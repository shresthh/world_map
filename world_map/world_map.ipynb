# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0MB 8.3MB/s
# ...
#      |████████████████████████████████| 6.5MB 24.6MB/s
# ...
#      |████████████████████████████████| 15.3MB 301kB/s
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import geopandas as gpd
import plotly.express as px
import pandas as pd

# %%
world_data_lowres = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
world_data_cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
world_data_cities.head()
# Out:
#            name                   geometry
# 0  Vatican City  POINT (12.45339 41.90328)
# 1    San Marino  POINT (12.44177 43.93610)
# 2         Vaduz   POINT (9.51667 47.13372)
# 3    Luxembourg   POINT (6.13000 49.61166)
# 4       Palikir  POINT (158.14997 6.91664)

# %%
world_data_lowres.head()
# Out:
#      pop_est  ...                                           geometry
# 0     920938  ...  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1   53950935  ...  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2     603253  ...  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3   35623680  ...  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  326625791  ...  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 6 columns]

# %%
world_data_lowres.shape
# Out:
# (177, 6)

# %%
world_data_cities.shape
# Out:
# (202, 2)

# %%
axis = world_data_lowres.plot(
    color = 'lightblue',
     edgecolor = 'black'
)

# %%
world_data_lowres.plot(color = ".8")

# %%
world_data_lowres.plot(column = "pop_est")

# %%
world_data_lowres.plot(column = "pop_est", legend  = True)
